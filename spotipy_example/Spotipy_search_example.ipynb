# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_id = '<--use_yours-->'
client_secret = '<--use_yours-->'
sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(client_id=client_id, client_secret=client_secret))

# %% [markdown]
# ***Search for Track***

# %%
track_name = "Tallahassee Love"
artist_name = "T-Pain"
results = sp.search(q=f'track:{track_name} artist:{artist_name}', type='track')

# %%
from pprint import pprint

# %% [markdown]
# ***Print the entire search results***

# %%
pprint(results)
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=track%3ATallahassee+Love+artist%3AT-Pain&type=track&offset=0&limit=10',
#             'items': [{'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3aQeKQSyrW4qWr35idm0cy'},
#                                               'href': 'https://api.spotify.com/v1/artists/3aQeKQSyrW4qWr35idm0cy',
#                                               'id': '3aQeKQSyrW4qWr35idm0cy',
#                                               'name': 'T-Pain',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:3aQeKQSyrW4qWr35idm0cy'}],
#                                  'available_markets': ['AR',
#                                                        'AU',
#                                                        'AT',
#                                                        'BE',
#                                                        'BO',
#                                                        'BR',
#                                                        'BG',
#                                                        'CA',
#                                                        'CL',
#                                                        'CO',
#                                                        'CR',
#                                                        'CY',
#                                                        'CZ',
#                                                        'DK',
#                                                        'DO',
#                                                        'DE',
#                                                        'EC',
#                                                        'EE',
#                                                        'SV',
#                                                        'FI',
#                                                        'FR',
#                                                        'GR',
#                                                        'GT',
#                                                        'HN',
#                                                        'HK',
#                                                        'HU',
#                                                        'IS',
#                                                        'IE',
#                                                        'IT',
#                                                        'LV',
#                                                        'LT',
#                                                        'LU',
#                                                        'MY',
#                                                        'MT',
#                                                        'MX',
#                                                        'NL',
#                                                        'NZ',
#                                                        'NI',
#                                                        'NO',
#                                                        'PA',
#                                                        'PY',
#                                                        'PE',
#                                                        'PH',
#                                                        'PL',
#                                                        'PT',
#                                                        'SG',
#                                                        'SK',
#                                                        'ES',
#                                                        'SE',
#                                                        'CH',
#                                                        'TW',
#                                                        'TR',
#                                                        'UY',
#                                                        'US',
#                                                        'GB',
#                                                        'AD',
#                                                        'LI',
#                                                        'MC',
#                                                        'ID',
#                                                        'JP',
#                                                        'TH',
#                                                        'VN',
#                                                        'RO',
#                                                        'IL',
#                                                        'ZA',
#                                                        'SA',
#                                                        'AE',
#                                                        'BH',
#                                                        'QA',
#                                                        'OM',
#                                                        'KW',
#                                                        'EG',
#                                                        'MA',
#                                                        'DZ',
#                                                        'TN',
#                                                        'LB',
#                                                        'JO',
#                                                        'PS',
#                                                        'IN',
#                                                        'BY',
#                                                        'KZ',
#                                                        'MD',
#                                                        'UA',
#                                                        'AL',
#                                                        'BA',
#                                                        'HR',
#                                                        'ME',
#                                                        'MK',
#                                                        'RS',
#                                                        'SI',
#                                                        'KR',
#                                                        'BD',
#                                                        'PK',
#                                                        'LK',
#                                                        'GH',
#                                                        'KE',
#                                                        'NG',
#                                                        'TZ',
#                                                        'UG',
#                                                        'AG',
#                                                        'AM',
#                                                        'BS',
#                                                        'BB',
#                                                        'BZ',
#                                                        'BT',
#                                                        'BW',
#                                                        'BF',
#                                                        'CV',
#                                                        'CW',
#                                                        'DM',
#                                                        'FJ',
#                                                        'GM',
#                                                        'GE',
#                                                        'GD',
#                                                        'GW',
#                                                        'GY',
#                                                        'HT',
#                                                        'JM',
#                                                        'KI',
#                                                        'LS',
#                                                        'LR',
#                                                        'MW',
#                                                        'MV',
#                                                        'ML',
#                                                        'MH',
#                                                        'FM',
#                                                        'NA',
#                                                        'NR',
#                                                        'NE',
#                                                        'PW',
#                                                        'PG',
#                                                        'WS',
#                                                        'SM',
#                                                        'ST',
#                                                        'SN',
#                                                        'SC',
#                                                        'SL',
#                                                        'SB',
#                                                        'KN',
#                                                        'LC',
#                                                        'VC',
#                                                        'SR',
#                                                        'TL',
#                                                        'TO',
#                                                        'TT',
#                                                        'TV',
#                                                        'VU',
#                                                        'AZ',
#                                                        'BN',
#                                                        'BI',
#                                                        'KH',
#                                                        'CM',
#                                                        'TD',
#                                                        'KM',
#                                                        'GQ',
#                                                        'SZ',
#                                                        'GA',
#                                                        'GN',
#                                                        'KG',
#                                                        'LA',
#                                                        'MO',
#                                                        'MR',
#                                                        'MN',
#                                                        'NP',
#                                                        'RW',
#                                                        'TG',
#                                                        'UZ',
#                                                        'ZW',
#                                                        'BJ',
#                                                        'MG',
#                                                        'MU',
#                                                        'MZ',
#                                                        'AO',
#                                                        'CI',
#                                                        'DJ',
#                                                        'ZM',
#                                                        'CD',
#                                                        'CG',
#                                                        'IQ',
#                                                        'LY',
#                                                        'TJ',
#                                                        'VE',
#                                                        'ET',
#                                                        'XK'],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/6CrSEKCF4TYrbSIitegb3h'},
#                                  'href': 'https://api.spotify.com/v1/albums/6CrSEKCF4TYrbSIitegb3h',
#                                  'id': '6CrSEKCF4TYrbSIitegb3h',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b273baf2f329d4feeb19761eddf4',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e02baf2f329d4feeb19761eddf4',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d00004851baf2f329d4feeb19761eddf4',
#                                              'width': 64}],
#                                  'name': 'Epiphany (Expanded Edition)',
#                                  'release_date': '2007-06-05',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 20,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:6CrSEKCF4TYrbSIitegb3h'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3aQeKQSyrW4qWr35idm0cy'},
#                                     'href': 'https://api.spotify.com/v1/artists/3aQeKQSyrW4qWr35idm0cy',
#                                     'id': '3aQeKQSyrW4qWr35idm0cy',
#                                     'name': 'T-Pain',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:3aQeKQSyrW4qWr35idm0cy'}],
#                        'available_markets': ['AR',
#                                              'AU',
#                                              'AT',
#                                              'BE',
#                                              'BO',
#                                              'BR',
#                                              'BG',
#                                              'CA',
#                                              'CL',
#                                              'CO',
#                                              'CR',
#                                              'CY',
#                                              'CZ',
#                                              'DK',
#                                              'DO',
#                                              'DE',
#                                              'EC',
#                                              'EE',
#                                              'SV',
#                                              'FI',
#                                              'FR',
#                                              'GR',
#                                              'GT',
#                                              'HN',
#                                              'HK',
#                                              'HU',
#                                              'IS',
#                                              'IE',
#                                              'IT',
#                                              'LV',
#                                              'LT',
#                                              'LU',
#                                              'MY',
#                                              'MT',
#                                              'MX',
#                                              'NL',
#                                              'NZ',
#                                              'NI',
#                                              'NO',
#                                              'PA',
#                                              'PY',
#                                              'PE',
#                                              'PH',
#                                              'PL',
#                                              'PT',
#                                              'SG',
#                                              'SK',
#                                              'ES',
#                                              'SE',
#                                              'CH',
#                                              'TW',
#                                              'TR',
#                                              'UY',
#                                              'US',
#                                              'GB',
#                                              'AD',
#                                              'LI',
#                                              'MC',
#                                              'ID',
#                                              'JP',
#                                              'TH',
#                                              'VN',
#                                              'RO',
#                                              'IL',
#                                              'ZA',
#                                              'SA',
#                                              'AE',
#                                              'BH',
#                                              'QA',
#                                              'OM',
#                                              'KW',
#                                              'EG',
#                                              'MA',
#                                              'DZ',
#                                              'TN',
#                                              'LB',
#                                              'JO',
#                                              'PS',
#                                              'IN',
#                                              'BY',
#                                              'KZ',
#                                              'MD',
#                                              'UA',
#                                              'AL',
#                                              'BA',
#                                              'HR',
#                                              'ME',
#                                              'MK',
#                                              'RS',
#                                              'SI',
#                                              'KR',
#                                              'BD',
#                                              'PK',
#                                              'LK',
#                                              'GH',
#                                              'KE',
#                                              'NG',
#                                              'TZ',
#                                              'UG',
#                                              'AG',
#                                              'AM',
#                                              'BS',
#                                              'BB',
#                                              'BZ',
#                                              'BT',
#                                              'BW',
#                                              'BF',
#                                              'CV',
#                                              'CW',
#                                              'DM',
#                                              'FJ',
#                                              'GM',
#                                              'GE',
#                                              'GD',
#                                              'GW',
#                                              'GY',
#                                              'HT',
#                                              'JM',
#                                              'KI',
#                                              'LS',
#                                              'LR',
#                                              'MW',
#                                              'MV',
#                                              'ML',
#                                              'MH',
#                                              'FM',
#                                              'NA',
#                                              'NR',
#                                              'NE',
#                                              'PW',
#                                              'PG',
#                                              'WS',
#                                              'SM',
#                                              'ST',
#                                              'SN',
#                                              'SC',
#                                              'SL',
#                                              'SB',
#                                              'KN',
#                                              'LC',
#                                              'VC',
#                                              'SR',
#                                              'TL',
#                                              'TO',
#                                              'TT',
#                                              'TV',
#                                              'VU',
#                                              'AZ',
#                                              'BN',
#                                              'BI',
#                                              'KH',
#                                              'CM',
#                                              'TD',
#                                              'KM',
#                                              'GQ',
#                                              'SZ',
#                                              'GA',
#                                              'GN',
#                                              'KG',
#                                              'LA',
#                                              'MO',
#                                              'MR',
#                                              'MN',
#                                              'NP',
#                                              'RW',
#                                              'TG',
#                                              'UZ',
#                                              'ZW',
#                                              'BJ',
#                                              'MG',
#                                              'MU',
#                                              'MZ',
#                                              'AO',
#                                              'CI',
#                                              'DJ',
#                                              'ZM',
#                                              'CD',
#                                              'CG',
#                                              'IQ',
#                                              'LY',
#                                              'TJ',
#                                              'VE',
#                                              'ET',
#                                              'XK'],
#                        'disc_number': 1,
#                        'duration_ms': 124066,
#                        'explicit': True,
#                        'external_ids': {'isrc': 'USJI10700389'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/1Z4wgZ4LR2CGpR35q2vEaW'},
#                        'href': 'https://api.spotify.com/v1/tracks/1Z4wgZ4LR2CGpR35q2vEaW',
#                        'id': '1Z4wgZ4LR2CGpR35q2vEaW',
#                        'is_local': False,
#                        'name': 'Tallahassee Love',
#                        'popularity': 35,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/b5df1ea7821d0e1d173345cab2d8a5934dd4f111?cid=7212551781ea43b59e821b4d4b71f265',
#                        'track_number': 1,
#                        'type': 'track',
#                        'uri': 'spotify:track:1Z4wgZ4LR2CGpR35q2vEaW'},
#                       {'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3aQeKQSyrW4qWr35idm0cy'},
#                                               'href': 'https://api.spotify.com/v1/artists/3aQeKQSyrW4qWr35idm0cy',
#                                               'id': '3aQeKQSyrW4qWr35idm0cy',
#                                               'name': 'T-Pain',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:3aQeKQSyrW4qWr35idm0cy'}],
#                                  'available_markets': ['AR',
#                                                        'AU',
#                                                        'AT',
#                                                        'BE',
#                                                        'BO',
#                                                        'BR',
#                                                        'BG',
#                                                        'CA',
#                                                        'CL',
#                                                        'CO',
#                                                        'CR',
#                                                        'CY',
#                                                        'CZ',
#                                                        'DK',
#                                                        'DO',
#                                                        'DE',
#                                                        'EC',
#                                                        'EE',
#                                                        'SV',
#                                                        'FI',
#                                                        'FR',
#                                                        'GR',
#                                                        'GT',
#                                                        'HN',
#                                                        'HK',
#                                                        'HU',
#                                                        'IS',
#                                                        'IE',
#                                                        'IT',
#                                                        'LV',
#                                                        'LT',
#                                                        'LU',
#                                                        'MY',
#                                                        'MT',
#                                                        'MX',
#                                                        'NL',
#                                                        'NZ',
#                                                        'NI',
#                                                        'NO',
#                                                        'PA',
#                                                        'PY',
#                                                        'PE',
#                                                        'PH',
#                                                        'PL',
#                                                        'PT',
#                                                        'SG',
#                                                        'SK',
#                                                        'ES',
#                                                        'SE',
#                                                        'CH',
#                                                        'TW',
#                                                        'TR',
#                                                        'UY',
#                                                        'US',
#                                                        'GB',
#                                                        'AD',
#                                                        'LI',
#                                                        'MC',
#                                                        'ID',
#                                                        'JP',
#                                                        'TH',
#                                                        'VN',
#                                                        'RO',
#                                                        'IL',
#                                                        'ZA',
#                                                        'SA',
#                                                        'AE',
#                                                        'BH',
#                                                        'QA',
#                                                        'OM',
#                                                        'KW',
#                                                        'EG',
#                                                        'MA',
#                                                        'DZ',
#                                                        'TN',
#                                                        'LB',
#                                                        'JO',
#                                                        'PS',
#                                                        'IN',
#                                                        'BY',
#                                                        'KZ',
#                                                        'MD',
#                                                        'UA',
#                                                        'AL',
#                                                        'BA',
#                                                        'HR',
#                                                        'ME',
#                                                        'MK',
#                                                        'RS',
#                                                        'SI',
#                                                        'KR',
#                                                        'BD',
#                                                        'PK',
#                                                        'LK',
#                                                        'GH',
#                                                        'KE',
#                                                        'NG',
#                                                        'TZ',
#                                                        'UG',
#                                                        'AG',
#                                                        'AM',
#                                                        'BS',
#                                                        'BB',
#                                                        'BZ',
#                                                        'BT',
#                                                        'BW',
#                                                        'BF',
#                                                        'CV',
#                                                        'CW',
#                                                        'DM',
#                                                        'FJ',
#                                                        'GM',
#                                                        'GE',
#                                                        'GD',
#                                                        'GW',
#                                                        'GY',
#                                                        'HT',
#                                                        'JM',
#                                                        'KI',
#                                                        'LS',
#                                                        'LR',
#                                                        'MW',
#                                                        'MV',
#                                                        'ML',
#                                                        'MH',
#                                                        'FM',
#                                                        'NA',
#                                                        'NR',
#                                                        'NE',
#                                                        'PW',
#                                                        'PG',
#                                                        'WS',
#                                                        'SM',
#                                                        'ST',
#                                                        'SN',
#                                                        'SC',
#                                                        'SL',
#                                                        'SB',
#                                                        'KN',
#                                                        'LC',
#                                                        'VC',
#                                                        'SR',
#                                                        'TL',
#                                                        'TO',
#                                                        'TT',
#                                                        'TV',
#                                                        'VU',
#                                                        'AZ',
#                                                        'BN',
#                                                        'BI',
#                                                        'KH',
#                                                        'CM',
#                                                        'TD',
#                                                        'KM',
#                                                        'GQ',
#                                                        'SZ',
#                                                        'GA',
#                                                        'GN',
#                                                        'KG',
#                                                        'LA',
#                                                        'MO',
#                                                        'MR',
#                                                        'MN',
#                                                        'NP',
#                                                        'RW',
#                                                        'TG',
#                                                        'UZ',
#                                                        'ZW',
#                                                        'BJ',
#                                                        'MG',
#                                                        'MU',
#                                                        'MZ',
#                                                        'AO',
#                                                        'CI',
#                                                        'DJ',
#                                                        'ZM',
#                                                        'CD',
#                                                        'CG',
#                                                        'IQ',
#                                                        'LY',
#                                                        'TJ',
#                                                        'VE',
#                                                        'ET',
#                                                        'XK'],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/2uEfwGvcXoCgyEoRt2NMeC'},
#                                  'href': 'https://api.spotify.com/v1/albums/2uEfwGvcXoCgyEoRt2NMeC',
#                                  'id': '2uEfwGvcXoCgyEoRt2NMeC',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b273b2ba55019a2bc7f564c021bb',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e02b2ba55019a2bc7f564c021bb',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d00004851b2ba55019a2bc7f564c021bb',
#                                              'width': 64}],
#                                  'name': 'Epiphany (Expanded Edition)',
#                                  'release_date': '2007-06-06',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 20,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:2uEfwGvcXoCgyEoRt2NMeC'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3aQeKQSyrW4qWr35idm0cy'},
#                                     'href': 'https://api.spotify.com/v1/artists/3aQeKQSyrW4qWr35idm0cy',
#                                     'id': '3aQeKQSyrW4qWr35idm0cy',
#                                     'name': 'T-Pain',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:3aQeKQSyrW4qWr35idm0cy'}],
#                        'available_markets': ['AR',
#                                              'AU',
#                                              'AT',
#                                              'BE',
#                                              'BO',
#                                              'BR',
#                                              'BG',
#                                              'CA',
#                                              'CL',
#                                              'CO',
#                                              'CR',
#                                              'CY',
#                                              'CZ',
#                                              'DK',
#                                              'DO',
#                                              'DE',
#                                              'EC',
#                                              'EE',
#                                              'SV',
#                                              'FI',
#                                              'FR',
#                                              'GR',
#                                              'GT',
#                                              'HN',
#                                              'HK',
#                                              'HU',
#                                              'IS',
#                                              'IE',
#                                              'IT',
#                                              'LV',
#                                              'LT',
#                                              'LU',
#                                              'MY',
#                                              'MT',
#                                              'MX',
#                                              'NL',
#                                              'NZ',
#                                              'NI',
#                                              'NO',
#                                              'PA',
#                                              'PY',
#                                              'PE',
#                                              'PH',
#                                              'PL',
#                                              'PT',
#                                              'SG',
#                                              'SK',
#                                              'ES',
#                                              'SE',
#                                              'CH',
#                                              'TW',
#                                              'TR',
#                                              'UY',
#                                              'US',
#                                              'GB',
#                                              'AD',
#                                              'LI',
#                                              'MC',
#                                              'ID',
#                                              'JP',
#                                              'TH',
#                                              'VN',
#                                              'RO',
#                                              'IL',
#                                              'ZA',
#                                              'SA',
#                                              'AE',
#                                              'BH',
#                                              'QA',
#                                              'OM',
#                                              'KW',
#                                              'EG',
#                                              'MA',
#                                              'DZ',
#                                              'TN',
#                                              'LB',
#                                              'JO',
#                                              'PS',
#                                              'IN',
#                                              'BY',
#                                              'KZ',
#                                              'MD',
#                                              'UA',
#                                              'AL',
#                                              'BA',
#                                              'HR',
#                                              'ME',
#                                              'MK',
#                                              'RS',
#                                              'SI',
#                                              'KR',
#                                              'BD',
#                                              'PK',
#                                              'LK',
#                                              'GH',
#                                              'KE',
#                                              'NG',
#                                              'TZ',
#                                              'UG',
#                                              'AG',
#                                              'AM',
#                                              'BS',
#                                              'BB',
#                                              'BZ',
#                                              'BT',
#                                              'BW',
#                                              'BF',
#                                              'CV',
#                                              'CW',
#                                              'DM',
#                                              'FJ',
#                                              'GM',
#                                              'GE',
#                                              'GD',
#                                              'GW',
#                                              'GY',
#                                              'HT',
#                                              'JM',
#                                              'KI',
#                                              'LS',
#                                              'LR',
#                                              'MW',
#                                              'MV',
#                                              'ML',
#                                              'MH',
#                                              'FM',
#                                              'NA',
#                                              'NR',
#                                              'NE',
#                                              'PW',
#                                              'PG',
#                                              'WS',
#                                              'SM',
#                                              'ST',
#                                              'SN',
#                                              'SC',
#                                              'SL',
#                                              'SB',
#                                              'KN',
#                                              'LC',
#                                              'VC',
#                                              'SR',
#                                              'TL',
#                                              'TO',
#                                              'TT',
#                                              'TV',
#                                              'VU',
#                                              'AZ',
#                                              'BN',
#                                              'BI',
#                                              'KH',
#                                              'CM',
#                                              'TD',
#                                              'KM',
#                                              'GQ',
#                                              'SZ',
#                                              'GA',
#                                              'GN',
#                                              'KG',
#                                              'LA',
#                                              'MO',
#                                              'MR',
#                                              'MN',
#                                              'NP',
#                                              'RW',
#                                              'TG',
#                                              'UZ',
#                                              'ZW',
#                                              'BJ',
#                                              'MG',
#                                              'MU',
#                                              'MZ',
#                                              'AO',
#                                              'CI',
#                                              'DJ',
#                                              'ZM',
#                                              'CD',
#                                              'CG',
#                                              'IQ',
#                                              'LY',
#                                              'TJ',
#                                              'VE',
#                                              'ET',
#                                              'XK'],
#                        'disc_number': 1,
#                        'duration_ms': 124066,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'USJI10700394'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/7k4JYV37B6YHK6qMEyENE4'},
#                        'href': 'https://api.spotify.com/v1/tracks/7k4JYV37B6YHK6qMEyENE4',
#                        'id': '7k4JYV37B6YHK6qMEyENE4',
#                        'is_local': False,
#                        'name': 'Tallahassee Love',
#                        'popularity': 9,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/8ad00b6f0357b7cdf87eaebf93378a7f31e3c506?cid=7212551781ea43b59e821b4d4b71f265',
#                        'track_number': 1,
#                        'type': 'track',
#                        'uri': 'spotify:track:7k4JYV37B6YHK6qMEyENE4'}],
#             'limit': 10,
#             'next': None,
#             'offset': 0,
#             'previous': None,
#             'total': 2}}

# %% [markdown]
# The `[0]` in `['tracks']['items'][0]['album']['images'][0]` is used to access the first item in a list. In this specific context, it's navigating through the structure of the Spotify API response.
#
# Let's break it down:
#
# `['tracks']:` This accesses the 'tracks' key in the dictionary.
#
# `['items']:` This accesses the 'items' key within the 'tracks' dictionary. This is often a list of tracks.
#
# `[0]:` This accesses the first item in the list of tracks.
#
# `['album']:` This accesses the 'album' key within the first track.
#
# `['images']:` This accesses the 'images' key within the 'album' dictionary. This is often a list of images associated with the album cover.
#
# `[0]:` This accesses the first item in the list of images.
#
# So, `['tracks']['items'][0]['album']['images'][0]` is essentially specifying the details of the first image associated with the album of the first track in the search results. If there are multiple images, you might see `[1], [2]`, and so on to access additional images. The `[0]` is used to get the details of the first image in this case.this case.

# %% [markdown]
# ## Save the output to a file

# %%
import sys

# %%
with open('output.txt', 'w') as file:
    sys.stdout = file
    pprint(results)
    sys.stdout = sys.__stdout__
